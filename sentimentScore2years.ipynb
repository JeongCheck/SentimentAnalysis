# %%
import random
import numpy as np 

import time
import datetime
import pandas as pd
import os
from tqdm import tqdm

# %%
pj_path = os.getenv('HOME') + '/Projects/JeongCheck'
data_path = pj_path + '/prediction_data_nsmc'

# %%
file_list = os.listdir(data_path)
print(len(file_list))
file_list
# Out:
# 15
# ['water_pred.csv',
#  'art_pred.csv',
#  'oworld_pred.csv',
#  'observatory_pred.csv',
#  'dongchundang_pred.csv',
#  'hanbat_pred.csv',
#  'yuseong_pred.csv',
#  'expo_pred.csv',
#  'gyejok_pred.csv',
#  'daecheong_pred.csv',
#  'jangtae_pred.csv',
#  'uineungjeongi_pred.csv',
#  'science_pred.csv',
#  'ppuri_pred.csv',
#  'sungsimdang_pred.csv']

# %%
places = []
for file in file_list:
    tmp = file.split('_')[0]
    places.append(tmp)

# %%
places
# Out:
# ['water',
#  'art',
#  'oworld',
#  'observatory',
#  'dongchundang',
#  'hanbat',
#  'yuseong',
#  'expo',
#  'gyejok',
#  'daecheong',
#  'jangtae',
#  'uineungjeongi',
#  'science',
#  'ppuri',
#  'sungsimdang']

# %%
test = pd.read_csv(data_path + f'/{file_list[0]}')
test.head()
# Out:
#    Unnamed: 0   name  ratings   date  \
# 0           0    김성주        5  9시간 전
# 1           1    서알콩        5   1일 전
# 2           2    윤설희        5   2일 전
# 3           3    이상훈        4   2일 전
# 4           4  송순이공주        5   2일 전
#
#                                         comment        search       keyword  \
# 0                         가편하게 산책과 등산을 할 수 있는 곳  계룡산국립공원수통골지구  water_barrel
# 1                             커피 한잔하기 딱 좋은 거리에요  계룡산국립공원수통골지구  water_barrel
# 2                                    비 오고 난 수통골  계룡산국립공원수통골지구  water_barrel
# 3            가족 나들이하기 정말 좋은 곳 국립공원이라 관리도 잘 돼있네요  계룡산국립공원수통골지구  water_barrel
# 4  동네라서 자주 가는데 갈 때마다 좋은 곳이에요 이번에는 뱀이 나와서 좀 놀랐어요  계룡산국립공원수통골지구  water_barrel
#
#    label  pred
# 0      1     1
# 1      1     1
# 2      1     0
# 3      1     1
# 4      1     1

# %%
# 시간 일 주 달 년 
# 년이 들어가고 & 숫자가 2 초과면 이후, 아니면 이전 

test['date'] = test['date'].apply(lambda row : 'after' if '년' in str(row) and re.sub('[가-힣]', '', str(row)) >= str(2) else 'before')

# %%
test.head()
# Out:
#    Unnamed: 0   name  ratings    date  \
# 0           0    김성주        5  before
# 1           1    서알콩        5  before
# 2           2    윤설희        5  before
# 3           3    이상훈        4  before
# 4           4  송순이공주        5  before
#
#                                         comment        search       keyword  \
# 0                         가편하게 산책과 등산을 할 수 있는 곳  계룡산국립공원수통골지구  water_barrel
# 1                             커피 한잔하기 딱 좋은 거리에요  계룡산국립공원수통골지구  water_barrel
# 2                                    비 오고 난 수통골  계룡산국립공원수통골지구  water_barrel
# 3            가족 나들이하기 정말 좋은 곳 국립공원이라 관리도 잘 돼있네요  계룡산국립공원수통골지구  water_barrel
# 4  동네라서 자주 가는데 갈 때마다 좋은 곳이에요 이번에는 뱀이 나와서 좀 놀랐어요  계룡산국립공원수통골지구  water_barrel
#
#    label  pred
# 0      1     1
# 1      1     1
# 2      1     0
# 3      1     1
# 4      1     1

# %%
test[test.date == 'after']
# Out:
#      Unnamed: 0                name  ratings   date  \
# 541         541               mi Ya        3  after
# 542         542         Gideon Moon        5  after
# 543         543                  설다        4  after
# 544         544            Ji A Lim        5  after
# 545         545  Moonmok James Park        4  after
# ..          ...                 ...      ...    ...
# 680         680                 김태규        4  after
# 681         681                 김뚱이        5  after
# 682         682                 이시형        5  after
# 683         683        Park Sangbae        4  after
# 684         684     hyun seung shin        3  after
#
#                                                comment  search       keyword  \
# 541                                           산책하기 굿이요  수통골유원지  water_barrel
# 542  계룡산 국립공원 중 작고 산책하기 좋은 곳 나름 식당과 카페가 있어 산책하고 식사 ...  수통골유원지  water_barrel
# 543  도심과 가까운 자연 그대로의 안위적인 모습은 찾아보기 힘든 물론 물길을 만들고 위에...  수통골유원지  water_barrel
# 544                                                 좋음  수통골유원지  water_barrel
# 545                                           언제나 좋은 곳  수통골유원지  water_barrel
# ..                                                 ...     ...           ...
# 680                                  완만한 산책 등산 먹거리 좋아요  수통골유원지  water_barrel
# 681                           가깝고 깨끗하게 정리도 잘 되어있어서 좋아요  수통골유원지  water_barrel
# 682                                  가끔 산책하러 가는 수통골이에요  수통골유원지  water_barrel
# 683  등산을 목적으로 한다면 다녀올만함 여러 코스가 있으니 취향과 체력에 맞춰서 다녀오시...  수통골유원지  water_barrel
# 684                                  좋은 산책길 간단한 등산도 가능  수통골유원지  water_barrel
#
#      label  pred
# 541      1     1
# 542      1     1
# 543      1     1
# 544      1     1
# 545      1     1
# ..     ...   ...
# 680      1     1
# 681      1     1
# 682      1     1
# 683      0     0
# 684      1     1
#
# [144 rows x 9 columns]

# %%
after_test = test[test.date == 'after']
before_test = test[test.date == 'before']

# %%
def sentimentScore(df):
    data_len = len(df)
    data_label = df.label.sum()
    score = (data_label / data_len) *100
    return '%0.2f' %score

# %% [markdown]
# - 함수 테스트

# %%
score = sentimentScore(test)
score
# Out:
# '94.89'

# %%
for place, file_name in zip(places, file_list):
    print(file_name)
# Out:
# water_pred.csv
# art_pred.csv
# oworld_pred.csv
# observatory_pred.csv
# dongchundang_pred.csv
# hanbat_pred.csv
# yuseong_pred.csv
# expo_pred.csv
# gyejok_pred.csv
# daecheong_pred.csv
# jangtae_pred.csv
# uineungjeongi_pred.csv
# science_pred.csv
# ppuri_pred.csv
# sungsimdang_pred.csv

# %% [markdown]
# ## 리뷰 개수 확인 및 감성분석 점수 계산

# %%
score_dict = {}
for place, file_name in zip(places, file_list):
    tmp_data = pd.read_csv(data_path + f'/{file_name}')
    tmp_data['date'] = tmp_data['date'].apply(lambda row : 'after' if '년' in str(row) and re.sub('[가-힣]', '', str(row)) >= str(2) else 'before')
    
    before_tmp = tmp_data[tmp_data.date == 'before']
    after_tmp = tmp_data[tmp_data.date == 'after']
    print('before len :', len(before_tmp))
    print('after len :', len(after_tmp))
    
    print(f'##### 여행지 : {place}#####')
    bf_score = sentimentScore(before_tmp)
    af_score = sentimentScore(after_tmp)
    
    score_dict[place] = [bf_score, af_score]
# Out:
# before len : 541
# after len : 144
# ##### 여행지 : water#####
# before len : 448
# after len : 375
# ##### 여행지 : art#####
# before len : 444
# after len : 0
# ##### 여행지 : oworld#####
# before len : 15
# after len : 11
# ##### 여행지 : observatory#####
# before len : 219
# after len : 108
# ##### 여행지 : dongchundang#####
# before len : 402
# after len : 0
# ##### 여행지 : hanbat#####
# before len : 389
# after len : 40
# ##### 여행지 : yuseong#####
# before len : 511
# after len : 269
# ##### 여행지 : expo#####
# before len : 276
# after len : 195
# ##### 여행지 : gyejok#####
# before len : 229
# after len : 260
# ##### 여행지 : daecheong#####
# before len : 510
# after len : 0
# ##### 여행지 : jangtae#####
# before len : 323
# after len : 10
# ##### 여행지 : uineungjeongi#####
# before len : 381
# after len : 0
# ##### 여행지 : science#####
# before len : 426
# after len : 0
# ##### 여행지 : ppuri#####
# before len : 1592
# after len : 267
# ##### 여행지 : sungsimdang#####
# /home/aiffel-dj26/anaconda3/envs/aiffel/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in long_scalars
#   after removing the cwd from sys.path.

# %% [markdown]
# ### {여행지 : [코로나 이전감성분석 점수, 코로나 이후 감성분석 점수]}

# %%
score_dict
# Out:
# {'water': ['96.12', '90.28'],
#  'art': ['82.59', '78.40'],
#  'oworld': ['81.76', 'nan'],
#  'observatory': ['86.67', '100.00'],
#  'dongchundang': ['91.78', '97.22'],
#  'hanbat': ['88.56', 'nan'],
#  'yuseong': ['89.97', '92.50'],
#  'expo': ['77.10', '70.26'],
#  'gyejok': ['92.75', '95.38'],
#  'daecheong': ['86.46', '76.92'],
#  'jangtae': ['90.00', 'nan'],
#  'uineungjeongi': ['69.04', '60.00'],
#  'science': ['88.19', 'nan'],
#  'ppuri': ['85.45', 'nan'],
#  'sungsimdang': ['83.42', '82.77']}
